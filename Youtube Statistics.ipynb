# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Global Youtube Statistics.csv" , encoding = "latin-1")

# %%
df.head()# shows rows of the csv files from the top
# Out:
#    rank                    Youtuber  subscribers  video views  \
# 0     1                    T-Series    245000000 228000000000
# 1     2              YouTube Movies    170000000            0
# 2     3                     MrBeast    166000000  28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000 164000000000
# 4     5                   SET India    159000000 148000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                       2000000
# ...

# %%
df.tail()# shows rows from bottom we can add the number of rows we want to see , eg df.tail(10)
# Out:
#      rank                  Youtuber  subscribers  video views        category  \
# 990   991             Natan por Aï¿     12300000   9029609749          Sports
# 991   992  Free Fire India Official     12300000   1674409945  People & Blogs
# 992   993                     Panda     12300000   2214684303             NaN
# 993   994               RobTopGames     12300000    374123483          Gaming
# 994   995              Make Joke Of     12300000   2129773714          Comedy
#
#                         Title  uploads         Country Abbreviation  \
# 990             Natan por Aï¿     1200          Brazil           BR
# 991  Free Fire India Official     1500           India           IN
# 992               HybridPanda     2452  United Kingdom           GB
# 993               RobTopGames       39          Sweden           SE
# 994              Make Joke Of       62           India           IN
#
#       channel_type  ...  subscribers_for_last_30_days  created_year  \
# ...

# %%
df.info() # provide complete information of the csv file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe() # describe the table with aggregation
# Out:
#        rank  subscribers  video views  uploads  video_views_rank  \
# count   995          995          995      995               994
# mean    498     22982412  11039537052     9187            554249
# std     287     17526105  14110844377    34151           1362782
# min       1     12300000            0        0                 1
# 25%     250     14500000   4288145410      194               323
# 50%     498     17700000   7760819588      729               916
# 75%     746     24600000  13554701853     2668              3584
# max     995    245000000 228000000000   301308           4057944
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count           879                962                               939
# mean            386                746                         175610285
# std            1232               1944                         416378166
# min               1                  1                                 1
# ...

# %%
df.isna()# sho the data if its null or not by saying true or false
# Out:
#       rank  Youtuber  subscribers  video views  category  Title  uploads  \
# 0    False     False        False        False     False  False    False
# 1    False     False        False        False     False  False    False
# 2    False     False        False        False     False  False    False
# 3    False     False        False        False     False  False    False
# 4    False     False        False        False     False  False    False
# ..     ...       ...          ...          ...       ...    ...      ...
# 990  False     False        False        False     False  False    False
# 991  False     False        False        False     False  False    False
# 992  False     False        False        False      True  False    False
# 993  False     False        False        False     False  False    False
# 994  False     False        False        False     False  False    False
#
#      Country  Abbreviation  channel_type  ...  subscribers_for_last_30_days  \
# ...

# %%
df.isna().sum() # is na shows false boolean when the entries are not null and sum() shows how many rows of that column are null in number
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.duplicated() # give the duplicates in bool type
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# Length: 995, dtype: bool

# %%
df.duplicated().sum() # it shows overall we dont have any duplicates
# Out:
# np.int64(0)

# %%
df.columns # showcases all the columns from the csv file
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
pd.set_option("display.float_format","{:,.3f}".format) # data type formatting to receive the result infloat with 3 decimal values

# %%
category_subscribers_mean = df.groupby("category")["subscribers"].mean() # we found mean for the category of subscribers using groupby
category_subscribers_mean
# Out:
# category
# Autos & Vehicles        17,850,000.000
# Comedy                  20,123,188.406
# Education               26,542,222.222
# Entertainment           21,403,319.502
# Film & Animation        28,584,782.609
# Gaming                  20,852,127.660
# Howto & Style           19,390,000.000
# Movies                  25,650,000.000
# Music                   25,717,821.782
# News & Politics         20,630,769.231
# Nonprofits & Activism   27,750,000.000
# People & Blogs          21,056,060.606
# Pets & Animals          18,100,000.000
# Science & Technology    18,617,647.059
# Shows                   41,615,384.615
# Sports                  27,109,090.909
# Trailers                39,000,000.000
# Travel & Events         12,500,000.000
# Name: subscribers, dtype: float64

# %%
category_subscribers_mean.sort_values(ascending = False, inplace=True) # sort the order using sort and setting ascending= False for descending order and saving it in csv with the help of inplace=True

# %%
category_subscribers_mean.head(10).plot(kind = "bar") # used bar chart
plt.title("Mean Subscribers By Category")
plt.xlabel("Category")
plt.ylabel("Mean Subscribers")
plt.xticks(rotation=90)
plt.show()

# %%
channel_type_counts = df["channel_type"].value_counts() # used count aggregate function
channel_type_counts
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_counts.head(10).plot(kind = "pie", autopct= "%1.1f%%") # used pie chart
plt.title("Channel Type Distribution")
plt.show()

# %%
plt.scatter(df["subscribers"].head(10),df["video views"].head(10)) # used scatter plot
plt.title("Scatter Plot Of Subscribers Vs Video Views")
plt.xlabel("Subscribers")
plt.ylabel("Videos View")
plt.show()

# %%
country_subscribers_total = df.groupby("Country")["subscribers"].sum().sort_values(ascending = False) # used sum aggregate function
country_subscribers_total
# Out:
# Country
# United States           7329500000
# India                   4310600000
# Brazil                  1221800000
# United Kingdom           917400000
# Mexico                   626900000
# Indonesia                534100000
# South Korea              481700000
# Russia                   407200000
# Thailand                 386500000
# Spain                    385100000
# Canada                   363900000
# Argentina                328500000
# Colombia                 264500000
# Philippines              240100000
# Japan                    189100000
# Saudi Arabia             179100000
# Australia                172000000
# Pakistan                 155400000
# United Arab Emirates     148200000
# Ukraine                  125600000
# Germany                  116400000
# Turkey                    91600000
# Chile                     87200000
# France                    83900000
# Jordan                    67000000
# Sweden                    63000000
# ...

# %%
country_subscribers_total.head(10).plot(kind = "bar")
plt.title("Total Subscribers By Country")
plt.xlabel("Country")
plt.ylabel("Total Subscribers")
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby("created_year")["subscribers"].mean().sort_values(ascending = True) # used mean function
# Out:
# created_year
# 2,022.000   13,640,000.000
# 2,021.000   18,573,913.043
# 2,019.000   18,639,393.939
# 2,017.000   18,666,176.471
# 2,014.000   20,618,367.347
# 2,010.000   20,670,833.333
# 2,015.000   21,247,945.205
# 2,020.000   21,350,000.000
# 2,011.000   21,800,000.000
# 2,018.000   23,060,869.565
# 2,016.000   23,101,298.701
# 2,009.000   23,105,769.231
# 2,008.000   23,652,173.913
# 2,012.000   24,038,235.294
# 2,013.000   24,527,631.579
# 2,007.000   24,902,040.816
# 2,005.000   25,829,166.667
# 2,006.000   31,884,615.385
# 1,970.000   36,300,000.000
# Name: subscribers, dtype: float64

# %%
df.groupby("channel_type")["video_views_rank"].median().sort_values(ascending =False) # median function
# Out:
# channel_type
# Autos           3,468,229.000
# Tech                2,420.000
# Games               1,944.000
# People              1,868.000
# Howto               1,574.500
# Nonprofit           1,537.500
# Sports              1,186.000
# Comedy              1,033.000
# Film                  880.000
# Entertainment         796.000
# News                  611.500
# Education             538.000
# Music                 385.000
# Animals               136.000
# Name: video_views_rank, dtype: float64

# %%
df.groupby("Country")["subscribers_for_last_30_days"].max().sort_values(ascending = False) # used max aggregate function
# Out:
# Country
# United States          8,000,000.000
# Indonesia              5,500,000.000
# United Arab Emirates   3,400,000.000
# South Korea            3,200,000.000
# Sweden                 3,000,000.000
# Turkey                 2,100,000.000
# Italy                  2,000,000.000
# India                  2,000,000.000
# Argentina              1,900,000.000
# Colombia               1,600,000.000
# Russia                 1,600,000.000
# Pakistan               1,300,000.000
# Kuwait                 1,300,000.000
# Latvia                 1,200,000.000
# Brazil                 1,100,000.000
# Japan                  1,100,000.000
# Germany                  900,000.000
# Spain                    800,000.000
# Australia                600,000.000
# United Kingdom           600,000.000
# Mexico                   600,000.000
# Philippines              500,000.000
# Saudi Arabia             500,000.000
# Chile                    500,000.000
# Canada                   400,000.000
# ...

# %%
df.groupby("created_month")["subscribers"].sum() # applied sum aggregate function
# Out:
# created_month
# Apr    1581200000
# Aug    1813600000
# Dec    1577300000
# Feb    1533800000
# Jan    2254600000
# Jul    1922300000
# Jun    1846400000
# Mar    2320500000
# May    1997700000
# Nov    1930200000
# Oct    1503700000
# Sep    2496200000
# Name: subscribers, dtype: int64

# %%
df.groupby("category")["video views"].std() # standard deviation function
# Out:
# category
# Autos & Vehicles         2,964,425,983.842
# Comedy                   6,406,251,669.423
# Education               25,572,139,026.298
# Entertainment           10,128,204,611.479
# Film & Animation        10,899,550,880.906
# Gaming                   5,835,933,598.166
# Howto & Style            4,300,326,961.462
# Movies                   3,353,301,875.455
# Music                   17,782,784,424.310
# News & Politics          5,165,961,804.903
# Nonprofits & Activism    2,698,145,850.473
# People & Blogs          12,510,420,847.248
# Pets & Animals           6,475,165,093.463
# Science & Technology     2,937,981,619.124
# Shows                   43,723,894,661.845
# Sports                  21,703,831,459.301
# Trailers                 1,382,496,086.178
# Travel & Events                        NaN
# Name: video views, dtype: float64

# %%
df.groupby("Country")["Unemployment rate"].min().sort_values(ascending = True) # used min aggregate function
# Out:
# Country
# Thailand                0.750
# Cuba                    1.640
# Vietnam                 2.010
# Philippines             2.150
# Kuwait                  2.180
# Japan                   2.290
# United Arab Emirates    2.350
# Germany                 3.040
# Netherlands             3.200
# Peru                    3.310
# Malaysia                3.320
# Mexico                  3.420
# United Kingdom          3.850
# Ecuador                 3.970
# El Salvador             4.110
# Singapore               4.110
# South Korea             4.150
# Bangladesh              4.190
# China                   4.320
# Pakistan                4.450
# Switzerland             4.580
# Russia                  4.590
# Indonesia               4.690
# Australia               5.270
# India                   5.360
# Canada                  5.560
# Saudi Arabia            5.930
# Sweden                  6.480
# Latvia                  6.520
# Finland                 6.590
# ...

# %%
df.groupby("channel_type")["uploads"].sum()
# Out:
# channel_type
# Animals            42868
# Autos                949
# Comedy             81722
# Education         146355
# Entertainment    3345035
# Film              114654
# Games             399473
# Howto              79417
# Music             424950
# News             3989151
# Nonprofit         205824
# People            117424
# Sports            158995
# Tech               33780
# Name: uploads, dtype: int64

# %%
df.groupby(["Latitude" , "Longitude"]).size() # For each (Latitude, Longitude) pair, it counts how many rows belong to that pair.
# Out:
# Latitude  Longitude
# -38.416   -63.617       13
# -35.675   -71.543        3
# -25.274   133.775        9
# -14.235   -51.925       62
# -13.759   -172.105       1
# -9.190    -75.015        1
# -1.831    -78.183        2
# -0.789    113.921       28
# 1.352     103.820        3
# 4.210     101.976        1
# 4.571     -74.297       11
# 6.424     -66.590        1
# 12.880    121.774       12
# 13.194    -59.543        1
# 13.794    -88.897        1
# 14.058    108.277        3
# 15.870    100.993       18
# 20.594    78.963       168
# 21.522    -77.781        1
# 23.424    53.848         7
# 23.635    -102.553      33
# 23.685    90.356         1
# 23.886    45.079         9
# 26.821    30.802         2
# 29.312    47.482         1
# 30.375    69.345         6
# 30.585    36.238         3
# 31.792    -7.093         1
# 33.223    43.679         2
# 33.939    67.710         1
# 35.862    104.195        1
# 35.908    127.767       17
# 36.205    138.253        5
# ...

# %%
sns.boxplot(x="channel_type" , y="highest_monthly_earnings", data=df,  hue="channel_type", palette="Set2",dodge=False) # hue adds color differentiation by 'channel_type'
    # palette="Set2",  Specifies the color palette
   # dodge=False   Ensures all boxplots for the same category are stacked together
plt.title("Distribution of Highest Monthly Earning by Channel Type")
plt.xticks(rotation = 90)
plt.legend([], [], frameon=False) # Hiding the legend (can be customized or removed entirely if unnecessary)
plt.show() # Its a boxplot

# %%
df.groupby(["category" , "Country"])["subscribers"].sum().unstack().plot(kind = "bar", stacked = True) # unstack make a column format
plt.title("Subscribers Breakdown By Category and Country")
plt.xlabel("Category")
plt.ylabel("Total Subscribers")
plt.legend(title = "Country" , bbox_to_anchor = (1.05, 1), loc = "upper left")
plt.xticks(rotation = 90)
plt.show() # stacked bar chart

# %%
plt.scatter(df["Gross tertiary education enrollment (%)"],df["subscribers"], alpha= 0.5) # uses as a parameter to show the transparency level of visual
plt.title("Scatter Plot Of Subscribers Vs Gross Tertiary Education Enrollment")
plt.xlabel("Gross Tertiary Education Enrollment")
plt.ylabel("Subscribers")
plt.show()

# %%
df.groupby("channel_type")["Unemployment rate"].mean().sort_values(ascending = False).plot(kind = "bar")
plt.title("Average Unemployment Rate By Channel Type")
plt.xlabel("Channel Type")
plt.ylabel("Average Unemployment Rate")
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby(["created_year","channel_type"])["subscribers"].mean().unstack().tail().plot(kind = "bar" , width = 1) # multicoulmn
plt.title("Average Subscribers By Created Year And Channel Type")
plt.xlabel("Created Year")
plt.ylabel("Average_Subscribers")
plt.xticks(rotation = 45)
plt.legend(title = "Channel Type",bbox_to_anchor = (1.05,1), loc="upper left")
plt.show()

# %%
df.groupby(["created_year" , "created_month"])["subscribers"].sum().unstack().plot(kind = "area", stacked = True)
plt.title("Subscribers Growth Over Time")
plt.xlabel("Year")
plt.ylabel("Total Subscribers")
plt.legend(title = "Month", bbox_to_anchor = (1.05,1), loc = "upper left")
plt.xticks(rotation = 45)
plt.show()

# %%
df.groupby(["created_year" , "Country"])["highest_yearly_earnings"].mean().unstack().head().plot(kind = "line" ,marker="o")
plt.title("Trend Of Highest Yearly Earnings by Created Year and Country")
plt.xlabel("Created Year")
plt.ylabel("Average Highest Yearly Earnings")
plt.legend(title = "Country", bbox_to_anchor =(1.05,1) , loc = "upper left")
plt.xticks(rotation= 45)
plt.show()

# %%
category_highest_monthly_earnings_sum = df.groupby("category")["highest_monthly_earnings"].sum().sort_values(ascending= False )
category_highest_monthly_earnings_sum
# Out:
# category
# Entertainment           150,056,865.140
# Music                   111,564,523.950
# People & Blogs           72,183,154.160
# Comedy                   46,113,543.000
# Film & Animation         33,704,283.220
# Education                31,283,000.100
# Shows                    26,489,600.000
# Gaming                   25,559,111.380
# News & Politics          16,708,431.000
# Sports                    8,876,300.000
# Howto & Style             7,711,962.340
# Science & Technology      3,434,735.000
# Pets & Animals            3,177,729.000
# Autos & Vehicles          2,172,700.000
# Movies                      909,400.000
# Nonprofits & Activism       780,800.000
# Trailers                    723,800.000
# Travel & Events             124,000.000
# Name: highest_monthly_earnings, dtype: float64

# %%
category_highest_monthly_earnings_sum.head().plot(kind = "pie", autopct= "%1.1f%%")
plt.title("Percentage Of Highest Monthly Earnings By Category")
plt.ylabel("")
plt.show()

# %%
channel_created_subscribers_mean = df.groupby(["channel_type","created_year"])["subscribers_for_last_30_days"].mean().unstack()

# %%
channel_created_subscribers_mean
# Out:
# created_year    1,970.000   2,005.000   2,006.000   2,007.000   2,008.000  \
# channel_type
# Animals               NaN         NaN         NaN         NaN         NaN
# Autos                 NaN         NaN       2.000 500,000.000         NaN
# Comedy                NaN 400,000.000 100,000.000 100,000.250 200,000.000
# Education             NaN         NaN 700,000.000         NaN 200,000.000
# Entertainment 300,000.000 325,000.000 306,250.500 342,857.286 450,000.000
# Film                  NaN       1.000 333,333.333         NaN 100,000.000
# Games                 NaN 100,000.000     337.667  50,005.500 100,000.000
# Howto                 NaN 500,000.000         NaN         NaN         NaN
# Music                 NaN 160,000.200 433,333.667 146,159.615 185,384.846
# News                  NaN 100,000.000 205,000.000 440,000.000 100,000.000
# Nonprofit             NaN         NaN         NaN         NaN         NaN
# ...

# %%
sns.heatmap(channel_created_subscribers_mean.head(2), cmap = "YlGnBu", annot= True)
plt.title("Mean Subscribers For Last 30 Days by Channel Type and Created Year")
plt.xlabel("Created Year")
plt.ylabel("Channel Type")
plt.show()

# %%
df.groupby("created_month")["subscribers_for_last_30_days"].mean().plot(kind="line",marker="o")
plt.title("Average Subscribers for Last 30 Days by Month")
plt.xlabel("Month")
plt.ylabel("Average Subscribers for Last 30 Days")
plt.xticks(rotation = 45)
plt.show()
